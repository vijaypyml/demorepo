# %% [markdown]
# # Package

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading csv file using pandas

# %%
df=pd.read_csv("HR-Employee-Attrition.csv")

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
future_prediction_data=df[1401:1470]
df=df[:1400]

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# # Dataset Characteristics

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1400 non-null   int64
#  1   Attrition                 1400 non-null   object
#  2   BusinessTravel            1400 non-null   object
#  3   DailyRate                 1400 non-null   int64
#  4   Department                1400 non-null   object
#  5   DistanceFromHome          1400 non-null   int64
#  6   Education                 1400 non-null   int64
#  7   EducationField            1400 non-null   object
#  8   EmployeeCount             1400 non-null   int64
#  9   EmployeeNumber            1400 non-null   int64
#  10  EnvironmentSatisfaction   1400 non-null   int64
#  11  Gender                    1400 non-null   object
#  12  HourlyRate                1400 non-null   int64
#  13  JobInvolvement            1400 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1400.000000  1400.000000       1400.000000  1400.000000         1400.0
# mean     36.930714   807.206429          9.168571     2.911429            1.0
# std       9.175997   403.237601          8.042872     1.026113            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   468.500000          2.000000     2.000000            1.0
# 50%      36.000000   808.000000          7.000000     3.000000            1.0
# 75%      43.000000  1163.250000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1400.000000              1400.000000  1400.000000     1400.000000
# mean       975.132857                 2.717143    65.867857        2.732143
# ...

# %% [markdown]
# # Splitting categorical and Numerical columns

# %%
cols = df.columns

df_numeric=df.select_dtypes(include=['int64', 'float64']).columns
#joined columns numeric and non numeric
df_categorical=df.select_dtypes(exclude=['int64', 'float64']).columns
new = df_numeric.tolist() + df_categorical.tolist()

# %%
df_numeric
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df_categorical
# Out:
# Index(['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender',
#        'JobRole', 'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
df[df_categorical]
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1395       Yes  Travel_Frequently                   Sales      Marketing
# 1396       Yes      Travel_Rarely                   Sales  Life Sciences
# 1397        No      Travel_Rarely  Research & Development  Life Sciences
# 1398        No  Travel_Frequently  Research & Development  Life Sciences
# 1399        No      Travel_Rarely  Research & Development  Life Sciences
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %% [markdown]
# # Analysing Categorical variable Characteristics

# %%
for i in df_categorical:
    print(i+ "column have " ,end='')
    print(df[i].unique(),end="")
    print(" values",'\n')
# Out:
# Attritioncolumn have ['Yes' 'No'] values
#
# BusinessTravelcolumn have ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel'] values
#
# Departmentcolumn have ['Sales' 'Research & Development' 'Human Resources'] values
#
# EducationFieldcolumn have ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources'] values
#
# Gendercolumn have ['Female' 'Male'] values
#
# JobRolecolumn have ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources'] values
#
# MaritalStatuscolumn have ['Single' 'Married' 'Divorced'] values
#
# Over18column have ['Y'] values
#
# OverTimecolumn have ['Yes' 'No'] values

# %%
for i in df_categorical:
    print(df[i].value_counts(),"\n")
# Out:
# No     1168
# Yes     232
# Name: Attrition, dtype: int64
#
# Travel_Rarely        991
# Travel_Frequently    268
# Non-Travel           141
# Name: BusinessTravel, dtype: int64
#
# Research & Development    917
# Sales                     424
# Human Resources            59
# Name: Department, dtype: int64
#
# Life Sciences       579
# Medical             441
# Marketing           150
# Technical Degree    129
# Other                76
# Human Resources      25
# Name: EducationField, dtype: int64
#
# Male      838
# Female    562
# Name: Gender, dtype: int64
#
# Sales Executive              310
# Research Scientist           279
# Laboratory Technician        246
# Manufacturing Director       139
# Healthcare Representative    125
# Manager                       99
# Sales Representative          77
# Research Director             76
# Human Resources               49
# Name: JobRole, dtype: int64
#
# Married     635
# Single      450
# Divorced    315
# ...

# %% [markdown]
# # visualization package

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set(style="darkgrid")
ax=sns.countplot(x='Attrition',data=df)
plt.show()

# %%
# df['Over18'] need to remove from data set

# %% [markdown]
# # categorical encodings

# %%
#Attrition 
df['Attrition'] = df['Attrition'].map( {'Yes':1, 'No':0})

# %%
df[df_categorical]
# Out:
#       Attrition     BusinessTravel              Department EducationField  \
# 0             1      Travel_Rarely                   Sales  Life Sciences
# 1             0  Travel_Frequently  Research & Development  Life Sciences
# 2             1      Travel_Rarely  Research & Development          Other
# 3             0  Travel_Frequently  Research & Development  Life Sciences
# 4             0      Travel_Rarely  Research & Development        Medical
# ...         ...                ...                     ...            ...
# 1395          1  Travel_Frequently                   Sales      Marketing
# 1396          1      Travel_Rarely                   Sales  Life Sciences
# 1397          0      Travel_Rarely  Research & Development  Life Sciences
# 1398          0  Travel_Frequently  Research & Development  Life Sciences
# 1399          0      Travel_Rarely  Research & Development  Life Sciences
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['Gender'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('Gender',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Male'],
#       dtype='object')

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['BusinessTravel'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('BusinessTravel',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['Department'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('Department',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['EducationField'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('EducationField',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['JobRole'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('JobRole',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = pd.get_dummies(df['MaritalStatus'], drop_first=True)
# Drop column non_numeric_col as it is now encoded
df = df.drop('MaritalStatus',axis = 1)
# Join the encoded dataframe to X_train
df = df.join(onehotencoder)

# %%
#OverTime 
df['OverTime'] = df['OverTime'].map( {'Yes':1, 'No':0})

# %%
df = df.drop('Over18',axis = 1)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StandardHours', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'Male', 'Travel_Frequently', 'Travel_Rarely', 'Research & Development',
#        'Sales', 'Life Sciences', 'Marketing', 'Medical', 'Other',
#        'Technical Degree', 'Human Resources', 'Laboratory Technician',
#        'Manager', 'Manufacturing Director', 'Research Director',
#        'Research Scientist', 'Sales Executive', 'Sales Representative',
#        'Married', 'Single'],
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1400 non-null   int64
#  1   Attrition                 1400 non-null   int64
#  2   DailyRate                 1400 non-null   int64
#  3   DistanceFromHome          1400 non-null   int64
#  4   Education                 1400 non-null   int64
#  5   EmployeeCount             1400 non-null   int64
#  6   EmployeeNumber            1400 non-null   int64
#  7   EnvironmentSatisfaction   1400 non-null   int64
#  8   HourlyRate                1400 non-null   int64
#  9   JobInvolvement            1400 non-null   int64
#  10  JobLevel                  1400 non-null   int64
#  11  JobSatisfaction           1400 non-null   int64
#  12  MonthlyIncome             1400 non-null   int64
#  13  MonthlyRate               1400 non-null   int64
# ...

# %% [markdown]
# # Regression Characteristics

# %%
df_n=df[df_numeric]

# %%
df_n.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1400.000000  1400.000000       1400.000000  1400.000000         1400.0
# mean     36.930714   807.206429          9.168571     2.911429            1.0
# std       9.175997   403.237601          8.042872     1.026113            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   468.500000          2.000000     2.000000            1.0
# 50%      36.000000   808.000000          7.000000     3.000000            1.0
# 75%      43.000000  1163.250000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1400.000000              1400.000000  1400.000000     1400.000000
# mean       975.132857                 2.717143    65.867857        2.732143
# ...

# %%
df_n.hist(figsize=(20,20))
plt.show()

# %%
df_n['Age'].describe()
# Out:
# count    1400.000000
# mean       36.930714
# std         9.175997
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
import scipy.stats as stats

# %%
def diagnostic_plots(df, variable):
    
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist(bins=30)

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)

    plt.show()

# %%
for i in df_numeric:
    diagnostic_plots(df_n, i)
    print(i)
# Out:
# Age
# DailyRate
# DistanceFromHome
# Education
# EmployeeCount
# EmployeeNumber
# EnvironmentSatisfaction
# HourlyRate
# JobInvolvement
# JobLevel
# JobSatisfaction
# MonthlyIncome
# MonthlyRate
# NumCompaniesWorked
# PercentSalaryHike
# PerformanceRating
# RelationshipSatisfaction
# StandardHours
# StockOptionLevel
# TotalWorkingYears
# TrainingTimesLastYear
# WorkLifeBalance
# YearsAtCompany
# YearsInCurrentRole
# YearsSinceLastPromotion
# YearsWithCurrManager

# %%
df_n['DistanceFromHome_log']=np.log(df_n['DistanceFromHome'])

diagnostic_plots(df_n, 'DistanceFromHome_log')
# Out:
# <ipython-input-126-69b9086b0013>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_n['DistanceFromHome_log']=np.log(df_n['DistanceFromHome'])

# %% [markdown]
# # Applying Directly without any regression techniques

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1400 non-null   int64
#  1   Attrition                 1400 non-null   int64
#  2   DailyRate                 1400 non-null   int64
#  3   DistanceFromHome          1400 non-null   int64
#  4   Education                 1400 non-null   int64
#  5   EmployeeCount             1400 non-null   int64
#  6   EmployeeNumber            1400 non-null   int64
#  7   EnvironmentSatisfaction   1400 non-null   int64
#  8   HourlyRate                1400 non-null   int64
#  9   JobInvolvement            1400 non-null   int64
#  10  JobLevel                  1400 non-null   int64
#  11  JobSatisfaction           1400 non-null   int64
#  12  MonthlyIncome             1400 non-null   int64
#  13  MonthlyRate               1400 non-null   int64
# ...

# %%
X=df.drop('Attrition', axis=1)
y=df['Attrition']

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1395    1
# 1396    1
# 1397    0
# 1398    0
# 1399    0
# Name: Attrition, Length: 1400, dtype: int64

# %%
#original order of columns
cols = X.columns

X_numeric=X.select_dtypes(include=['int64', 'float']).columns
#joined columns numeric and non numeric
X_non_numeric=X.select_dtypes(exclude=['int64', 'float']).columns
new = X_numeric.tolist() + X_non_numeric.tolist()

# %%
df[X_non_numeric]=df[X_non_numeric].astype('object')
df[X_non_numeric].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Male                    1400 non-null   object
#  1   Travel_Frequently       1400 non-null   object
#  2   Travel_Rarely           1400 non-null   object
#  3   Research & Development  1400 non-null   object
#  4   Sales                   1400 non-null   object
#  5   Life Sciences           1400 non-null   object
#  6   Marketing               1400 non-null   object
#  7   Medical                 1400 non-null   object
#  8   Other                   1400 non-null   object
#  9   Technical Degree        1400 non-null   object
#  10  Human Resources         1400 non-null   object
#  11  Laboratory Technician   1400 non-null   object
#  12  Manager                 1400 non-null   object
#  13  Manufacturing Director  1400 non-null   object
# ...

# %%
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer

t = [('num', SimpleImputer(strategy='median'), X_numeric),
('cat', SimpleImputer(strategy='most_frequent'), X_non_numeric)]


transformer = ColumnTransformer(transformers=t, remainder='passthrough')

X = transformer.fit_transform(X) #numpy array

#DataFrame constructor with new columns names and added reindex for change by original order
X = pd.DataFrame(X, columns=new).reindex(cols, axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1400 non-null   object
#  1   DailyRate                 1400 non-null   object
#  2   DistanceFromHome          1400 non-null   object
#  3   Education                 1400 non-null   object
#  4   EmployeeCount             1400 non-null   object
#  5   EmployeeNumber            1400 non-null   object
#  6   EnvironmentSatisfaction   1400 non-null   object
#  7   HourlyRate                1400 non-null   object
#  8   JobInvolvement            1400 non-null   object
#  9   JobLevel                  1400 non-null   object
#  10  JobSatisfaction           1400 non-null   object
#  11  MonthlyIncome             1400 non-null   object
#  12  MonthlyRate               1400 non-null   object
# ...

# %% [markdown]
# # Heading

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=66)

# %%
y_test
# Out:
# 1364    0
# 961     0
# 985     1
# 302     0
# 644     0
#        ..
# 811     0
# 1362    0
# 1009    0
# 1238    0
# 603     0
# Name: Attrition, Length: 280, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr_clf = LogisticRegression(random_state = 0)
lr_clf.fit(X_train, y_train)

y_pred=lr_clf.predict(X_test)

# %%
print('Accuracy on training set:',lr_clf.score(X_train,y_train))
print('Accuracy on test set:',lr_clf.score(X_test,y_test))
# Out:
# Accuracy on training set: 0.8883928571428571
# Accuracy on test set: 0.8857142857142857

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[228,   8],
#        [ 24,  20]], dtype=int64)

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')
